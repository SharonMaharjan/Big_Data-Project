# %% [markdown]
# # **Fastai - From Data to DataLoaders (for images)**
#
# As always, first check if you have your GPU accelerator in Colab enabled.
# Second, run the cells below to activate the helper functions of fastai, and link it to GDrive.

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# Since we are going to import data, make sure you have a zip-file which contains your training data. The easiest way to import classification data, is to have a folder for each class you want to predict, and use the folder name as the label.
#
# So, for instance, if you want to make a classification model to predict a dog or a cat, with your own data: make a parentfolder 'data', and in that folder:a folder 'cat' with the cat images, and a folder 'dog' with the dog images. Zip that entire parentfolder, so you get a 'data.zip' file.
#
# ## Option 1: GDrive
#
# We could mount GDrive to Colab, and store our images there. But the I/O is just too slow (but check, because Google continuously changes this behavior). Note: for now (nov 2023), they fixed the latency issue, so the zip option into session memory, is no longer really needed.
#
# ## Option 2: zip file to session memory
#
# So we're going to upload this zip file 'data.zip' into our local Colab memory. Keep in mind: for large datasets this would be impossible, and we would therefore need our GCP account to store our data in buckets on the Google Cloud.
#
# To upload the 'data.zip' folder to local colab memory: look to the left of the screen, and click the Filefolder-icon. Click the 'upload to session-storage' icon, select your 'data.zip' file, and upload.
# Remember: this data will only stay here for the duration of our session.
# But that's long enough for our purposes.
#
# Now, let's unzip our data, so we can access it via our local session storage:

# %%
# !unzip /content/gdrive/MyDrive/BigDataDatasets.zip
# Out:
# Archive:  /content/gdrive/MyDrive/BigDataDatasets.zip
#    creating: data/
#    creating: data/celebrity tomato/
#   inflating: data/celebrity tomato/celebrity tomato_11.jpg
#   inflating: data/celebrity tomato/celebrity tomato_13.jpg
#   inflating: data/celebrity tomato/celebrity tomato_14.jpg
#   inflating: data/celebrity tomato/celebrity tomato_15.jpg
#   inflating: data/celebrity tomato/celebrity tomato_17.jpg
#   inflating: data/celebrity tomato/celebrity tomato_2.jpg
#   inflating: data/celebrity tomato/celebrity tomato_20.jpg
#   inflating: data/celebrity tomato/celebrity tomato_21.jpg
#   inflating: data/celebrity tomato/celebrity tomato_22.jpg
#   inflating: data/celebrity tomato/celebrity tomato_23.jpg
#   inflating: data/celebrity tomato/celebrity tomato_24.jpg
#   inflating: data/celebrity tomato/celebrity tomato_25.jpg
#   inflating: data/celebrity tomato/celebrity tomato_26.jpg
#   inflating: data/celebrity tomato/celebrity tomato_27.jpg
#   inflating: data/celebrity tomato/celebrity tomato_28.jpg
#   inflating: data/celebrity tomato/celebrity tomato_29.jpg
#   inflating: data/celebrity tomato/celebrity tomato_3.jpg
#   inflating: data/celebrity tomato/celebrity tomato_31.jpg
#   inflating: data/celebrity tomato/celebrity tomato_34.jpg
#   inflating: data/celebrity tomato/celebrity tomato_35.jpg
#   inflating: data/celebrity tomato/celebrity tomato_36.jpg
#   inflating: data/celebrity tomato/celebrity tomato_37.jpg
#   inflating: data/celebrity tomato/celebrity tomato_38.jpg
#   inflating: data/celebrity tomato/celebrity tomato_39.jpg
#   inflating: data/celebrity tomato/celebrity tomato_4.jpg
#   inflating: data/celebrity tomato/celebrity tomato_40.jpg
#   inflating: data/roma tomato/roma tomato_90.jpg
#   inflating: data/roma tomato/roma tomato_91.jpg
#   inflating: data/roma tomato/roma tomato_92.jpg
#   inflating: data/roma tomato/roma tomato_93.jpg
#   inflating: data/roma tomato/roma tomato_94.jpg
#   inflating: data/roma tomato/roma tomato_95.jpg
#   inflating: data/roma tomato/roma tomato_96.jpg
#   inflating: data/roma tomato/roma tomato_99.jpg
#    creating: data/yellow pear tomato/
#   inflating: data/yellow pear tomato/yellow pear tomato_1.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_10.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_11.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_12.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_13.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_15.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_16.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_17.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_18.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_2.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_20.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_21.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_23.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_24.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_25.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_26.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_27.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_28.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_29.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_3.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_30.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_31.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_33.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_35.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_36.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_37.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_38.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_4.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_41.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_42.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_44.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_45.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_46.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_47.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_48.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_49.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_5.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_50.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_51.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_52.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_53.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_55.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_58.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_59.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_60.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_63.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_64.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_66.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_68.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_69.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_72.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_74.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_75.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_76.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_79.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_8.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_81.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_82.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_83.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_84.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_85.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_86.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_87.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_88.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_89.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_9.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_90.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_91.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_92.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_93.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_95.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_97.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_98.jpg
#   inflating: data/yellow pear tomato/yellow pear tomato_99.jpg

# %% [markdown]
# After running the unzip command, it takes a few moments, but you should see your 'data' folder, with the cat and dog folder inside, pop up in the directory structure on the left.

# %% [markdown]
# Let's check one of the images (local colab session storage can be found in the '/content/' directory:

# %%
# If you want to use option1:
path = '/content/gdrive/MyDrive/Dataset/data/data/'

# %%
# If you want to use option2:
path = '/content/data/'

# %%
from PIL import Image

im = Image.open(path +'roma tomato/roma tomato_1.jpg')
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %% [markdown]
# To make life easier, let's make a variable *filenames* that contains a listing of all paths to all files in the data folder

# %%
from fastai.vision.all import *
filenames = get_image_files(path)
filenames
# Out:
# (#360) [Path('/content/data/green zebra tomato/green zebra tomato_91.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_89.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_86.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_67.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_47.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_43.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_31.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_52.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_51.jpg'),Path('/content/data/green zebra tomato/green zebra tomato_26.jpg')...]

# %% [markdown]
# And just as a sanity check, let's verify all the images, to make sure none of them are corrupt files:

# %%
failed = verify_images(filenames)
failed
# Out:
# (#0) []

# %% [markdown]
# # **DataLoaders**
#
# To read-in data for our modeling, fastai uses a wrapper class called 'DataLoaders', which can take whatever 'DataLoader' (notice the 's' or lack thereof) objects you pass to it (usually a `train` and a `valid`). And makes them available.
# So, in short: we need DataLoaders as a wrapper around our training and validation data, so other fastai functions can call upon them.
#
# If you want to check out the source code for this function:

# %%
??DataLoaders

# %% [markdown]
# Or just a quick summary of the doc:

# %%
# !pip install nbdev
# Out:
# Collecting nbdev
#   Downloading nbdev-2.3.13-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.1/66.1 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets<=8.0.4 in /usr/local/lib/python3.10/dist-packages (from nbdev) (7.7.1)
# Requirement already satisfied: fastcore>=1.5.27 in /usr/local/lib/python3.10/dist-packages (from nbdev) (1.5.29)
# Collecting execnb>=0.1.4 (from nbdev)
#   Downloading execnb-0.1.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.10/dist-packages (from nbdev) (1.6.3)
# Collecting ghapi>=1.0.3 (from nbdev)
#   Downloading ghapi-1.0.4-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 6.3 MB/s eta 0:00:00
# Collecting watchdog (from nbdev)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.2 MB/s eta 0:00:00
# Collecting asttokens (from nbdev)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from nbdev) (6.0.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from execnb>=0.1.4->nbdev) (7.34.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore>=1.5.27->nbdev) (23.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fastcore>=1.5.27->nbdev) (23.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<=8.0.4->nbdev) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<=8.0.4->nbdev) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<=8.0.4->nbdev) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<=8.0.4->nbdev) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<=8.0.4->nbdev) (3.0.9)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens->nbdev) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse->nbdev) (0.41.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (5.5.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.18.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<=8.0.4->nbdev) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->execnb>=0.1.4->nbdev) (0.2.10)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (4.0.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (2.19.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.13.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.0.4->nbdev) (2.21)
# Installing collected packages: watchdog, asttokens, ghapi, execnb, nbdev
# Successfully installed asttokens-2.4.1 execnb-0.1.5 ghapi-1.0.4 nbdev-2.3.13 watchdog-3.0.0

# %%
doc(DataLoaders)
# Out:
# <hr/>
# <h3>DataLoaders</h3>
# <blockquote><pre><code>DataLoaders(*loaders, path:str|pathlib.Path='.', device=None)</code></pre></blockquote><p>Basic wrapper around several `DataLoader`s.</p>
# <p><a href="https://docs.fast.ai/data.core.html#dataloaders" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %% [markdown]
# We already saw some *factory methods* for some common data import options in our previous notebook on taking fastai for a spin.
#
# ImageDataLoader using a self-defined function on the filenames to load all files in a folder, and add a label to them according to our function.
#
# ```python
# def is_cat(x): return x[0].isupper()
# dls = ImageDataLoaders.from_name_func(
#     path, get_image_files(path), valid_pct=0.2, seed=42,
#     label_func=is_cat, item_tfms=Resize(224))
# ```
#
# But we also saw other *factory-methods* of DataLoaders in action: TextDataLoaders, SegmentationDataLoaders, TabularDataLoaders, CollabDataLoaders.
#
# ```python
# dls = TextDataLoaders.from_folder(untar_data(URLs.IMDB), valid='test')
# dls = SegmentationDataLoaders.from_label_func(...)
# dls = TabularDataLoaders.from_csv(path/'adult.csv', path=path, y_names="salary",...)
# dls = CollabDataLoaders.from_csv(path/'ratings.csv')
# ```

# %% [markdown]
# # **Fastai data block API**
#
# So, as we can gather from these predetermined *factory methods*: to get our own data into a DataLoaders object, we need to tell fastai at least 4 things:
#
#
# 1.   What kind of data we are working with
# 2.   How to get all the data items
# 3.   How to label these items
# 4.   How to create the validation set
# 5.   Extra preprocessing, like resize
#
# Okay. Now, let's use a **custom, fully adjustable, way to create our own DataLoaders object**, so we don't need to use one of those pre-configured loaders. This is done in fastai by using the 'data block API'.
#
# I'll give you the code first, and then explain it line by line:

# %%
catdogs = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %% [markdown]
# ## 1. What kind of data we're working with
# Let's look at each of these arguments one by one. First we provide a tuple where we specify what types we want for the independent and dependent variables:
#
# ```python
# blocks=(ImageBlock, CategoryBlock)
# ```
#
# The *independent variable* is the thing we are using to make predictions from, and the *dependent variable* is our target. In this case, our independent variables are images, and our dependent variables are the categories (cat or dog) for each image. As you can imagine, there are other types of blocks as well (check the docs if interested). For instance, an ImageBlock, or a TextBlock, or for the targets: a MultiCategoryBlock, for multi-label categorical targets, or even a RegressionBlock.

# %% [markdown]
# ## 2.   How to get all the data items
#
# For this catdogs-`DataLoaders`-object, our underlying items will be file paths. We have to tell fastai how to get a list of those files. The `get_image_files` function takes a path, and returns a list of all of the images in that path (recursively, by default):
#
# ```python
# get_items=get_image_files
# ```

# %% [markdown]
# ## 3.   How to label these items
#
#
# The independent variable is often referred to as `X` and the dependent variable is often referred to as `y`. Here, we are telling fastai what function to call to create the labels in our dataset:
#
# ```python
# get_y=parent_label
# ```
#
# `parent_label` is a function provided by fastai that simply gets the name of the folder a file is in. Because we put each of our cat/dog images into folders based on the type of animal, this is going to give us the labels that we need. This a very common way to structure your input data, also on the Kaggle platform. That's why fastai has a build-in method for it. Pretty handy, no?

# %% [markdown]
# ## 4.   How to create the validation set
#
# We want to split our training and validation sets randomly. However, we would like to have the same training/validation split each time we run this notebook, so we fix the random seed (computers don't really know how to create random numbers at all, but simply create lists of numbers that look random; if you provide the same starting point for that list each time—called the *seed*—then you will get the exact same list each time):
#
#
# ```python
# splitter=RandomSplitter(valid_pct=0.2, seed=42)
# ```

# %% [markdown]
# ## 5. Extra preprocessing
#
# If you download / scrape images from the internet, they could all be of different sizes, and this is a problem for deep learning: we don't feed the model one image at a time but several of them at once (what we call a *mini-batch*).
#
# **To group them in a big array (a *tensor*), that is going to go through our model in parallel, they all need to be of the same size** (the library needs to know how many input-neurons it should have - this was the case when we used TensorFlow/Keras).
#
# So, we need to add a transform which will resize all these images to the same size. *Item transforms* (item_tfms) are pieces of code that run on each individual item, whether it's an image, category, or whatever.
#
# fastai includes many predefined transforms (handy to do data augmentation), but we'll use the `Resize` transform here, to resize all images to 128x128 pixels. We just want a uniform size, for now.
#
# ```python
# item_tfms=Resize(128)
# ```

# %%
doc(Resize)
# Out:
# <hr/>
# <h3>Resize</h3>
# <blockquote><pre><code>Resize(size:int|tuple, method:ResizeMethod='crop', pad_mode:PadMode='reflection', resamples=(<Resampling.BILINEAR: 2>, <Resampling.NEAREST: 0>), **kwargs)</code></pre></blockquote><p>A transform that before_call its state at each `__call__`</p>
# <p><a href="https://docs.fast.ai/vision.augment.html#resize" target="_blank" rel="noreferrer noopener">Show in docs</a></p>

# %% [markdown]
# Alright, so now we have our `DataBlock` object *catdogs*. This is like a boilerplate, or a template to create our custom `DataLoaders`. All we have to do now, is feed it the path to where it can find the data, and it will take care of the rest: loading the data into train/valid sets we can directly use in fastai, which will hand it over as tensors to the GPU's to do their magic.
#
# Awesome!
# Let's load it up, Scotty!

# %%
dls = catdogs.dataloaders(path)

# %% [markdown]
# By default, fastai will load 64 images at a time, stacked up as one big multidimensional tensor. So default batch_size = 64.
#
# Let's do a quick sanity check of our data

# %%
dls.train.show_batch(max_n=4, nrows=1)
dls.valid.show_batch(max_n=4, nrows=1)

# %% [markdown]
# ### Extra part on preprocessing
#
# Ofcourse, default resizing to a square 128x128 isn't always the best option, because by default the resizing operation *crops* (cutting off pieces) to images to the requested size. Sometimes images are really rectangular, and that forced cropping, can really *morph* your images.
#
# We can try Squishing instead of cropping, or padding with 'zero's', but these are kind of wastefull: squishing will *morph* our images for sure, and than our model won't detect correct patterns. And padding is just empty space, but we still need lot's of calculations (the convolutions) to calculate with it, but it's just pure empty space, so a complete waste of resources...

# %%
#code block below is just for demonstration purposes. Best NOT to use Squishing in your own dataloader
catdogs = catdogs.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = catdogs.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
#code block below is just for demonstration purposes. Best NOT to use zero padding in your own dataloader
catdogs = catdogs.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = catdogs.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1)
dls.valid.show_batch(max_n=4, nrows=1)

# %% [markdown]
# In fact, trials and research show, it's usually best to do a kind of random Resized cropping. So randomly selecting a part of the image, and crop to just that part. But ofcourse, because it's random, every epoch (epoch = one entire run through all your data), another random section of the image is chosen. So every epoch your network will focus on different parts of the images. Best is to give this transform a minimum size, the absolute minimum piece of the image it can crop it down to, otherwise it might randomly select a teeny tiny piece...
#
# This is kind of an augmentation technique (which is also a regularization technique = preventing overfitting or fixating on certain features)

# %%
catdogs = catdogs.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = catdogs.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)
# the unique=True piece here is just to force our sanity check to give us the same image over and over again,
# ofcourse each time with the random transform applied to it

# %% [markdown]
# As a recap: the best way to import your own custom dataset, using best in class options, is:

# %%
customDataset = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=RandomResizedCrop(128, min_scale=0.3))

dls = customDataset.dataloaders(path)

dls.train.show_batch(max_n=4, nrows=1)
dls.valid.show_batch(max_n=4, nrows=1)

# %% [markdown]
# Awesome! Now we're making some headway!
#
# Ofcourse, we can add some more augmentation to really level-up on the input quality, but that's for another notebook.
#
# Let's just wrap things up with this notebook, with a simple out of the box convolutional neural net, using transfer-learning (see later lesson), so using a resnet with pretrained weights, fine-tune it automatically, and let's just see how good our model already is (without any tweaking, but already using state-of-the-art-out-of-the-box options)...
#
# Next time, we'll level up on these techniques, but for now, let's just use an out of the box technique...

# %%
our_out_of_the_box_model = vision_learner(dls, resnet50, metrics=error_rate)
our_out_of_the_box_model.fine_tune(5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.335200</td>
#       <td>0.865232</td>
#       <td>0.277778</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.189955</td>
#       <td>0.673531</td>
#       <td>0.250000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.939962</td>
#       <td>0.498724</td>
#       <td>0.208333</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.804763</td>
#       <td>0.390112</td>
#       <td>0.166667</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.694547</td>
#       <td>0.374810</td>
#       <td>0.152778</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.624861</td>
#       <td>0.409195</td>
#       <td>0.194444</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(our_out_of_the_box_model)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# Okay, this is just on a tiny dataset...but not bad...Only one or two (depends on your random selected data) wrong out of the 20 on the validation set...let's see which ones our model has most difficulties with...

# %%
interp.plot_top_losses(5, nrows=5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# (if the top losses function only draws one image, check: https://forums.fast.ai/t/plot-top-losses-problem/92015/10 for a fix)
#
#
#
# Okay. Fair enough...probably with some more data, and augmentation techniques, and some more awesome level_ups we would be better at this...but not bad at all for our first run at it!
#
# Let's save and export our model, so we can deploy it later to be used in a webpage.

# %%
# saving our model, by default in a folder called 'models'.
our_out_of_the_box_model.save('first_model')
#creating an serialized pickle object of our model, the export.pkl file
our_out_of_the_box_model.export()

# %% [markdown]
# Make sure you manually download the export.pkl file (and the first_model.pth if need be)! Because Colab will remove files in its session memory after the session is complete. Plus, later on, we will run a Flask API service on our local machine, so we need the serialized model.

# %%
ls
# Out:
# data/  export.pkl  gdrive/  models/  sample_data/

# %% [markdown]
# # **Loading a model & inference:**

# %%
our_out_of_the_box_model_inference = load_learner('export.pkl')
# let's test our model on an image
our_out_of_the_box_model_inference.predict(path + 'roma tomato/roma tomato_1.jpg')
# this will return the predicted category, the index of this predicted category, and the probabilities of each category
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('roma tomato', tensor(3), tensor([0.1294, 0.0025, 0.0026, 0.8282, 0.0373]))

# %%
our_out_of_the_box_model_inference.dls.vocab
# Out:
# ['celebrity tomato', 'green zebra tomato', 'pineapple tomato', 'roma tomato', 'yellow pear tomato']

# %% [markdown]
# Alright! So we can load our serialized model, hand it an image, and it will return a prediction.
#
# Next step is ofcourse making a Python API wrapper around this model, so we can use JSON to upload an image, and get the predictions returned. This is where Flask comes in! Flask is a Python micro framework, with a really easy to use API wrapper.
#
# Now, you should already have enough information to go ahead and build a prototype of your Computer Vision project assignment! You could even start to research a little bit around Flask API and how they are used to 'deploy', or provide an interface to, a serialized (pickle) Deep Learning model...
