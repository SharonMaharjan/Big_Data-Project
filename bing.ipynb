# %%
# %pip install bing-image-downloader

from bing_image_downloader import downloader
downloader.download('yellow pear tomato', limit=150,  output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\sya-r\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [%] Downloading Images to c:\Big Data\Big_Data-Project\dataset\yellow pear tomato
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.rocketgardens.co.uk/wp-content/uploads/2016/02/Yellow-Pear-Tomato.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.growjoy.com/store/pc/catalog/yellow_pear_tomato_plant_1875_detail.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.shopify.com/s/files/1/2084/6123/products/SV650-yellow_pear_tomatoes_wood_table_1024x1024.jpg?v=1559855426
# [%] File Downloaded !
#
# ...
